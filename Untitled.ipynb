# %%
import os
print(os.getcwd())
# Out:
# C:\Users\mercy\Groundwater_Project

# %%
import os
print(os.listdir())
# Out:
# ['.ipynb_checkpoints', '01_data_cleaning.ipynb', 'data', 'models', 'notebooks', 'outputs', 'Untitled.ipynb']

# %%
print(os.listdir("data"))
# Out:
# []

# %%
import os
print(os.listdir("data"))
# Out:
# ['andhra_pradesh_district_population_2011.csv', 'andhra_rainfall_statistics.csv', 'apy_total.csv', 'ap_district_population.csv', 'crop report.csv', 'crop_production.csv', 'fertilizerstudy.csv', 'gwq_chemical_parameter.csv', 'gwq_physical_parameter_manual_cgwb_ap_1961_2025.csv', 'GW_DFMS_Levels_1776197327427.csv', 'GW_Levels_1776197307778.csv', 'rainfall_stats.csv', 'Rainfall_Summary_1776191812918.csv', 'shc vs actual.csv', 'Soil moisture summary_1776197357611.csv']
